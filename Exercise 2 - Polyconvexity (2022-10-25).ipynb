# %% [markdown]
# $$
# \DeclareMathOperator\tr{tr}
# \DeclareMathOperator\Tr{Tr}
# \DeclareMathOperator\cof{cof}
# \DeclareMathOperator\Cof{Cof}
# \DeclareMathOperator\det{det}
# \DeclareMathOperator\Det{Det}
# \DeclareMathOperator\dev{dev}
# \DeclareMathOperator\Dev{Dev}
# \DeclareMathOperator\sph{sph}
# \DeclareMathOperator\Sph{Sph}
# \newcommand{\bF}{\mathbf{F}}
# \newcommand{\bC}{\mathbf{C}}
# \newcommand{\bE}{\mathbf{E}}
# \newcommand{\bone}{\mathbf{1}}
# \newcommand{\bd}{\mathbf{d}}
# \newcommand{\bc}{\mathbf{c}}
# \newcommand{\bA}{\mathbf{A}}
# \newcommand{\bS}{\mathbf{S}}
# \newcommand{\Bsigma}{{\boldsymbol{\sigma}}}
# \newcommand{\pdiff}[2]{\frac{\partial#1}{\partial#2}}
# \nonumber
# $$

# %% [markdown]
# # Overview
#
# In this notebook we numerically investigate different hyperelastic material laws.

# %% [markdown]
# # General setup

# %%
# %matplotlib nbagg

# %%
from netgen import *
import netgen.occ as nocc
from netgen.webgui import Draw as DrawGeo

from ngsolve import *
from ngsolve.webgui import Draw
from ngsolve import solvers

import matplotlib.pyplot as plt
import numpy as np

# %%
cube = nocc.Box((-0.5, -0.5, -0.5), (0.5, 0.5, 0.5))

# %%
cube.faces.Max(nocc.X).bc("front")
cube.faces.Min(nocc.X).bc("back")
cube.faces.Max(nocc.Y).bc("right")
cube.faces.Min(nocc.Y).bc("left")
cube.faces.Max(nocc.Z).bc("top")
cube.faces.Min(nocc.Z).bc("bottom")

# %%
ngmesh = nocc.OCCGeometry(cube).GenerateMesh(maxh=0.5)

# %%
mesh = Mesh(ngmesh)

# %%
Draw(mesh)
# Out:
# WebGuiWidget(value={'gui_settings': {}, 'ngsolve_version': '6.2.2204', 'mesh_dim': 3, 'order2d': 1, 'order3d':…
# BaseWebGuiScene

# %%
order = 2

# %%
bc_boundaries = dict(
    dirichletx="back", 
    dirichlety="left", 
    dirichletz="bottom"
)

fes = VectorH1(mesh, order=order, **bc_boundaries)

# %%
#VectorH1?

# %%
u = GridFunction(fes) # stored displacement
u_trial = fes.TrialFunction() # displacement variable

# %% [markdown]
# # Material models
#
# For a unified interface we employ the right Cauchy-Green tensor as basic input together with a parameter dictionary.
#
#
# ## Isotropy, invariants
#
# The models under consideration describe isotropic materials. Hence, the strain energy densities
# must depends only on the "principal invariants", $I_1$, $I_2$ and $I_3$, of the right Cauchy-Green tensor
# \begin{equation}
# I_1 = \Tr \bC = ||\bF||^2, \quad I_2 = \Tr (\cof \bC) = ||\Cof\bF||^2 \quad \text{and} \quad I_3 = \Det \bC = \left(\Det \bF\right)^2 .
# \end{equation}
#
# An alternative expression for the second invariant is
# \begin{equation}
# I_2 = \frac{1}{2}\left(\Tr(\bC)^2 - (I_1)^2\right).
# \end{equation}
#
#
# *Note*: The invariants as defined above need some more careful discussion when we know a bit more about differential geometry.

# %%
def phi(u):
    return u + (x, y, z)

def F(phi):
    return Grad(phi)

def Fu(u):
    return Grad(u) + Id(3)

def C(F):
    return F.trans * F

def I_1(A):
    return Trace(A)

def I_2(A):
    return (I_1(A * A) - I_1(A)) / 2

def I_3(A):
    return Det(A)

# %% [markdown]
# ## St. Venant-Kirchhoff (SVK) material
#
# The "St. Venant-Kirchhoff" material is the most straight-forward extension of Hooke's law in the setting of linearized elasticity to finite strains.
# It's parameterization is based on the "Green-Lagrange" strain tensor that encodes the change of length as
# \begin{equation}
# \bE = \frac{1}{2} \left(\bC - \bone\right),
# \end{equation}
# where $\bC$ is the right Cauchy-Green tensor and $\bone$ the identity matrix.
#
# The strain energy density function is given as
# \begin{equation}
#  \Psi(\bE) = \frac{\lambda}{2} (\Tr{\bE})^2 + {\mu} \Tr{\left(\bE^2\right)}.
# \end{equation}

# %%
def Psi_SVK(C, **params):
    lmbda = params["lmbda"]
    mu = params["mu"]
    E = (C - Id(3)) / 2
    return lmbda/2 * Trace(E)**2 + mu * InnerProduct(E, E)

# %% [markdown]
# ## Neo-Hookean (NH) material
#
# This (class of) material model(s) is popular because of its theoretical properties and simplicity.
# It often is a good choice for "moderate" deformations (strains in the order of 100%).
#
# A compressible version reads
# \begin{equation}
# \Psi(\bC) = \frac{\mu}{2} \left(I_1 - 3 - \ln I_3\right) + \frac{\lambda}{8}\left(\ln I_3\right)^2 =
# \frac{\mu}{2} \left(I_1 - 3 - 2 \ln J\right) + \frac{\lambda}{2}\left(\ln J\right)^2,
# \end{equation}
# where $J = \Det\bF$.

# %%
def Psi_NH(C, **params):
    lmbda = params["lmbda"]
    mu = params["mu"]
    _I_1 = I_1(C)
    _ln_I_3 = log(I_3(C))
    return mu/2 * (_I_1 - 3 - _ln_I_3) + lmbda/8 * _ln_I_3**2

# %% [markdown]
# ## A note on material parameters
#
# Hyperelastic material models are often parameterized in terms of the *Lamé* parameters (or constants) $\lambda$ and $\mu$,
# whereby $\mu$ is also known as the shear modulus $G$.
# They are related to Young's modulus ("E-Modul") and Poisson's ratio via
# \begin{equation}
# \nu = \frac{\lambda}{2(\lambda + \mu)} \quad\text{and}\quad
# E = 2\mu(1+\nu) .
# \end{equation}

# %% [markdown]
# ## Questions
#
#  1. What are the expressions of the invariants in terms of the eigenvalues $\bF$ denoted as $\lambda_1$, $\lambda_2$ and $\lambda_3$?
#  2. Consider the deformation map $\varphi$ for which $\varphi^i(X^1, X^2, X^3) = \varphi^i(X^i)$. What are the expressions for $\lambda_\alpha$ in terms of $\varphi$? (Note: the index of lambda is rather a mere label than an index indicating a component)
#  3. In general, exponentiations of a tensor are computed by (i) transform to eigensystem, (ii) exponentiate eigenvalues and (iii) transform back. Why can $\bC^2$ be computed as $\bC^2 = \bC\cdot\bC$?
#  4. How does the St. Venant-Kirchhoff (SVK) material read in terms of invariants of $\bC$?
#  5. What is the expression for the second Piola-Kirchoff stress for the SVK model?
#  6. What is the expression for the Cauchy stress for the NH model?
#  7. What is the linearization of the Green-Lagrange strain tensor $\bE$ at $\bC = \bone$ expressed in terms of (incremental) displacements $(\Delta) u$? *Hint*: What special state does $\bC = \bone$ refer to?
#  7. What are the *linearizations* (material tangents; derivative of "stress" wrt. "strain") of the of the SVK and the NH models at $\bC = \bone$?

# %% [markdown]
# # Formulation of the governing potential (energy)
#
# In the present quasi-static settings, "equilibrium" is characterized by critical points of the total
# energy.
#
# Parameters to play with:
#  * loading direction/increment: sign/value of `dt`
#  * material model: def. of `Psi = lambda...`

# %%
mu = Parameter(1)
lmbda = Parameter(5)
Psi = lambda C: Psi_SVK(C, mu=mu, lmbda=lmbda)

# %%
Pi = BilinearForm(fes, symmetric=True)

# %% [markdown]
# ## Constitutive (material, internal) contribution

# %%
Pi += Variation(Psi(C(Fu(u_trial))) * dx(bonus_intorder=3))

# %% [markdown]
# ## Loading (external) potential

# %%
t_3 = Parameter(0)
Pi += Variation(- t_3 * u_trial[2] * ds(mesh.Boundaries("top")))

# %% [markdown]
# # Solution procedure

# %%
# record some data
from pkgutil import read_code


t_3_data = []
u_top_data = []

# load increment 
dt = -0.01

# initialize
t_3.Set(0)
u.vec[:] = 0

r = u.vec.CreateVector()
Pi.Apply(u.vec, r)
print(f"initial residual norm = {r.Norm():e}")

if r.Norm() > 1e-14:
    raise RuntimeError("Initial residual is not zero!")

while t_3.Get() < 10 + 1e-6: # have some tolerance
    print(f"Solve for t_3 = {t_3.Get():e}")
    retcode, iterations = solvers.Newton(Pi, u, maxit=10, inverse="pardiso")
    if retcode != 0:
        raise RuntimeError("Solver failed")
    t_3_data.append(t_3.Get())
    u_top_data.append(u(mesh(0, 0, 0.5))[2])
    print(retcode)
    print(f"top displacement u_3 = {u_top_data[-1]:e}")
    print("-" * 120)
    t_3.Set(t_3.Get() + dt)
# Out:
# initial residual norm = 0.000000e+00
# Solve for t_3 = 0.000000e+00
# Newton iteration  0
# err =  0.0
# 0
# top displacement u_3 = 0.000000e+00
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -1.000000e-02
# Newton iteration  0
# err =  0.005940885257859964
# Newton iteration  1
# err =  3.6356682182896376e-05
# Newton iteration  2
# err =  1.4431531964402412e-09
# Newton iteration  3
# err =  6.512355771998333e-16
# 0
# top displacement u_3 = -3.548275e-03
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -2.000000e-02
# Newton iteration  0
# err =  0.005972702794311201
# Newton iteration  1
# err =  3.716740977361688e-05
# Newton iteration  2
# err =  1.5273319833365094e-09
# Newton iteration  3
# err =  4.0522497872954227e-16
# 0
# top displacement u_3 = -7.135004e-03
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -3.000000e-02
# Newton iteration  0
# err =  0.006005272612821973
# Newton iteration  1
# err =  3.801255395265585e-05
# Newton iteration  2
# err =  1.618183826735181e-09
# Newton iteration  3
# err =  9.599222585344047e-16
# 0
# top displacement u_3 = -1.076132e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -4.000000e-02
# Newton iteration  0
# err =  0.006038627218390391
# Newton iteration  1
# err =  3.889427233247986e-05
# Newton iteration  2
# err =  1.716382383426402e-09
# Newton iteration  3
# err =  3.111165518203434e-16
# 0
# top displacement u_3 = -1.442841e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -5.000000e-02
# Newton iteration  0
# err =  0.006072801185065569
# Newton iteration  1
# err =  3.981490349039187e-05
# Newton iteration  2
# err =  1.822684279661059e-09
# Newton iteration  3
# err =  6.171108772128767e-16
# 0
# top displacement u_3 = -1.813753e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -6.000000e-02
# Newton iteration  0
# err =  0.006107831331719563
# Newton iteration  1
# err =  4.077698613721322e-05
# Newton iteration  2
# err =  1.9379412567619856e-09
# Newton iteration  3
# err =  3.7760282669271613e-16
# 0
# top displacement u_3 = -2.188998e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -7.000000e-02
# Newton iteration  0
# err =  0.006143756916649708
# Newton iteration  1
# err =  4.1783280750704026e-05
# Newton iteration  2
# err =  2.063115038900935e-09
# Newton iteration  3
# err =  1.9240561272013453e-16
# 0
# top displacement u_3 = -2.568715e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -8.000000e-02
# Newton iteration  0
# err =  0.006180619853465147
# Newton iteration  1
# err =  4.283679406106699e-05
# Newton iteration  2
# err =  2.199293673976374e-09
# Newton iteration  3
# err =  2.9240043558137565e-16
# 0
# top displacement u_3 = -2.953049e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -9.000000e-02
# Newton iteration  0
# err =  0.006218464951090954
# Newton iteration  1
# err =  4.3940806823584284e-05
# Newton iteration  2
# err =  2.3477118380494087e-09
# Newton iteration  3
# err =  3.0865191144335306e-16
# 0
# top displacement u_3 = -3.342154e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -1.000000e-01
# Newton iteration  0
# err =  0.0062573401811645505
# Newton iteration  1
# err =  4.509890541119629e-05
# Newton iteration  2
# err =  2.5097728760710357e-09
# Newton iteration  3
# err =  3.3605353748531394e-16
# 0
# top displacement u_3 = -3.736191e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -1.100000e-01
# Newton iteration  0
# err =  0.006297296976634408
# Newton iteration  1
# err =  4.631501784240045e-05
# Newton iteration  2
# err =  2.687078854255992e-09
# Newton iteration  3
# err =  4.938516936365084e-16
# 0
# top displacement u_3 = -4.135332e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -1.200000e-01
# Newton iteration  0
# err =  0.00633839056599376
# Newton iteration  1
# err =  4.759345499581089e-05
# Newton iteration  2
# err =  2.8814614117633683e-09
# Newton iteration  3
# err =  4.0539068488195844e-16
# 0
# top displacement u_3 = -4.539757e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -1.300000e-01
# Newton iteration  0
# err =  0.006380680348332462
# Newton iteration  1
# err =  4.8938957883696195e-05
# Newton iteration  2
# err =  3.095023150154614e-09
# Newton iteration  3
# err =  1.330369179321481e-16
# 0
# top displacement u_3 = -4.949659e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -1.400000e-01
# Newton iteration  0
# err =  0.006424230315286067
# Newton iteration  1
# err =  5.035675205868976e-05
# Newton iteration  2
# err =  3.3301840957444405e-09
# Newton iteration  3
# err =  8.092371786893617e-16
# 0
# top displacement u_3 = -5.365242e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -1.500000e-01
# Newton iteration  0
# err =  0.00646910952703633
# Newton iteration  1
# err =  5.185261042493894e-05
# Newton iteration  2
# err =  3.589739305256799e-09
# Newton iteration  3
# err =  1.23923334893462e-16
# 0
# top displacement u_3 = -5.786721e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -1.600000e-01
# Newton iteration  0
# err =  0.006515392650815557
# Newton iteration  1
# err =  5.343292600016664e-05
# Newton iteration  2
# err =  3.876929616707812e-09
# Newton iteration  3
# err =  5.178006094682057e-16
# 0
# top displacement u_3 = -6.214328e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -1.700000e-01
# Newton iteration  0
# err =  0.006563160571941519
# Newton iteration  1
# err =  5.510479651288892e-05
# Newton iteration  2
# err =  4.195524953515837e-09
# Newton iteration  3
# err =  2.832591867032384e-16
# 0
# top displacement u_3 = -6.648307e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -1.800000e-01
# Newton iteration  0
# err =  0.0066125010893237895
# Newton iteration  1
# err =  5.687612312521153e-05
# Newton iteration  2
# err =  4.549928189578027e-09
# Newton iteration  3
# err =  1.723382446749947e-16
# 0
# top displacement u_3 = -7.088921e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -1.900000e-01
# Newton iteration  0
# err =  0.006663509709727171
# Newton iteration  1
# err =  5.875572609252784e-05
# Newton iteration  2
# err =  4.945303442839745e-09
# Newton iteration  3
# err =  3.7826986613271217e-16
# 0
# top displacement u_3 = -7.536451e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -2.000000e-01
# Newton iteration  0
# err =  0.0067162905579563545
# Newton iteration  1
# err =  6.075348083982536e-05
# Newton iteration  2
# err =  5.387732792474249e-09
# Newton iteration  3
# err =  2.69571954904893e-16
# 0
# top displacement u_3 = -7.991196e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -2.100000e-01
# Newton iteration  0
# err =  0.006770957423690974
# Newton iteration  1
# err =  6.28804787484127e-05
# Newton iteration  2
# err =  5.88441310740632e-09
# Newton iteration  3
# err =  2.0972123981296212e-16
# 0
# top displacement u_3 = -8.453480e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -2.200000e-01
# Newton iteration  0
# err =  0.006827634970124927
# Newton iteration  1
# err =  6.514921802962012e-05
# Newton iteration  2
# err =  6.443900791115906e-09
# Newton iteration  3
# err =  4.251254342875765e-16
# 0
# top displacement u_3 = -8.923648e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -2.300000e-01
# Newton iteration  0
# err =  0.006886460135101066
# Newton iteration  1
# err =  6.757383142370873e-05
# Newton iteration  2
# err =  7.076420609553165e-09
# Newton iteration  3
# err =  2.841096285534746e-16
# 0
# top displacement u_3 = -9.402076e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -2.400000e-01
# Newton iteration  0
# err =  0.0069475837624004095
# Newton iteration  1
# err =  7.017035922873437e-05
# Newton iteration  2
# err =  7.79425829820999e-09
# Newton iteration  3
# err =  3.3904351465729485e-16
# 0
# top displacement u_3 = -9.889167e-02
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -2.500000e-01
# Newton iteration  0
# err =  0.007011172509669724
# Newton iteration  1
# err =  7.295707849795096e-05
# Newton iteration  2
# err =  8.612260150260364e-09
# Newton iteration  3
# err =  5.580442254272054e-16
# 0
# top displacement u_3 = -1.038536e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -2.600000e-01
# Newton iteration  0
# err =  0.007077411090730594
# Newton iteration  1
# err =  7.595490226866081e-05
# Newton iteration  2
# err =  9.548477205698047e-09
# Newton iteration  3
# err =  7.339526018227175e-16
# 0
# top displacement u_3 = -1.089113e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -2.700000e-01
# Newton iteration  0
# err =  0.007146504924483454
# Newton iteration  1
# err =  7.918786673824434e-05
# Newton iteration  2
# err =  1.06250008828297e-08
# Newton iteration  3
# err =  2.7760029582315137e-16
# 0
# top displacement u_3 = -1.140699e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -2.800000e-01
# Newton iteration  0
# err =  0.0072186832813653365
# Newton iteration  1
# err =  8.268372970989992e-05
# Newton iteration  2
# err =  1.1869056811295601e-08
# Newton iteration  3
# err =  4.408962893162867e-16
# 0
# top displacement u_3 = -1.193351e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -2.900000e-01
# Newton iteration  0
# err =  0.007294203042812322
# Newton iteration  1
# err =  8.647471093577371e-05
# Newton iteration  2
# err =  1.3314450544613358e-08
# Newton iteration  3
# err =  5.108039916108868e-16
# 0
# top displacement u_3 = -1.247131e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -3.000000e-01
# Newton iteration  0
# err =  0.007373353221462549
# Newton iteration  1
# err =  9.059841497349276e-05
# Newton iteration  2
# err =  1.5003496562161832e-08
# Newton iteration  3
# err =  4.988140255383727e-16
# 0
# top displacement u_3 = -1.302108e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -3.100000e-01
# Newton iteration  0
# err =  0.007456460432816774
# Newton iteration  1
# err =  9.509899095160174e-05
# Newton iteration  2
# err =  1.6989621404894646e-08
# Newton iteration  3
# err =  6.277935908237291e-16
# 0
# top displacement u_3 = -1.358355e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -3.200000e-01
# Newton iteration  0
# err =  0.007543895566875826
# Newton iteration  1
# err =  0.00010002860289895648
# Newton iteration  2
# err =  1.9340915805307115e-08
# Newton iteration  3
# err =  8.551932132213304e-16
# 0
# top displacement u_3 = -1.415958e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -3.300000e-01
# Newton iteration  0
# err =  0.007636081986899409
# Newton iteration  1
# err =  0.00010544931153844935
# Newton iteration  2
# err =  2.2145045243774933e-08
# Newton iteration  3
# err =  1.0138475874904717e-15
# 0
# top displacement u_3 = -1.475007e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -3.400000e-01
# Newton iteration  0
# err =  0.007733505690654423
# Newton iteration  1
# err =  0.00011143550753440062
# Newton iteration  2
# err =  2.5516129807766194e-08
# Newton iteration  3
# err =  1.3157894294003347e-15
# 0
# top displacement u_3 = -1.535608e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -3.500000e-01
# Newton iteration  0
# err =  0.007836728020463679
# Newton iteration  1
# err =  0.0001180770931013526
# Newton iteration  2
# err =  2.9604528144997513e-08
# Newton iteration  3
# err =  1.937289139329727e-15
# 0
# top displacement u_3 = -1.597877e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -3.600000e-01
# Newton iteration  0
# err =  0.007946401721859883
# Newton iteration  1
# err =  0.00012548369310726434
# Newton iteration  2
# err =  3.461097784417069e-08
# Newton iteration  3
# err =  2.6503008564820065e-15
# 0
# top displacement u_3 = -1.661946e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -3.700000e-01
# Newton iteration  0
# err =  0.00806329145734964
# Newton iteration  1
# err =  0.00013379030366153608
# Newton iteration  2
# err =  4.080739946849524e-08
# Newton iteration  3
# err =  3.914946205086078e-15
# 0
# top displacement u_3 = -1.727964e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -3.800000e-01
# Newton iteration  0
# err =  0.008188300329834907
# Newton iteration  1
# err =  0.00014316498099279713
# Newton iteration  2
# err =  4.856811139945565e-08
# Newton iteration  3
# err =  5.681439084597102e-15
# 0
# top displacement u_3 = -1.796104e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -3.900000e-01
# Newton iteration  0
# err =  0.008322504637086845
# Newton iteration  1
# err =  0.00015381947900131287
# Newton iteration  2
# err =  5.84176905237408e-08
# Newton iteration  3
# err =  8.590236981086438e-15
# 0
# top displacement u_3 = -1.866563e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -4.000000e-01
# Newton iteration  0
# err =  0.008467200091637157
# Newton iteration  1
# err =  0.0001660242346801905
# Newton iteration  2
# err =  7.110615620874346e-08
# Newton iteration  3
# err =  1.3203671902493312e-14
# 0
# top displacement u_3 = -1.939574e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -4.100000e-01
# Newton iteration  0
# err =  0.008623964314703294
# Newton iteration  1
# err =  0.00018012990977426567
# Newton iteration  2
# err =  8.773032828072139e-08
# Newton iteration  3
# err =  2.1098487556999016e-14
# 0
# top displacement u_3 = -2.015407e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -4.200000e-01
# Newton iteration  0
# err =  0.008794742922223665
# Newton iteration  1
# err =  0.00019659907096728166
# Newton iteration  2
# err =  1.0993581327859642e-07
# Newton iteration  3
# err =  3.4801649893367905e-14
# 0
# top displacement u_3 = -2.094387e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -4.300000e-01
# Newton iteration  0
# err =  0.008981970637473653
# Newton iteration  1
# err =  0.00021605400213480798
# Newton iteration  2
# err =  1.4026514575456645e-07
# Newton iteration  3
# err =  5.986555970858254e-14
# 0
# top displacement u_3 = -2.176901e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -4.400000e-01
# Newton iteration  0
# err =  0.009188745839714515
# Newton iteration  1
# err =  0.00023935103657155105
# Newton iteration  2
# err =  1.8278244403223262e-07
# Newton iteration  3
# err =  1.0789674746282391e-13
# 0
# top displacement u_3 = -2.263429e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -4.500000e-01
# Newton iteration  0
# err =  0.009419089224065738
# Newton iteration  1
# err =  0.0002677001596979451
# Newton iteration  2
# err =  2.442478308931452e-07
# Newton iteration  3
# err =  2.0544653530704077e-13
# 0
# top displacement u_3 = -2.354561e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -4.600000e-01
# Newton iteration  0
# err =  0.009678339763993403
# Newton iteration  1
# err =  0.00030286536744523676
# Newton iteration  2
# err =  3.364504967752812e-07
# Newton iteration  3
# err =  4.1932015112460936e-13
# 0
# top displacement u_3 = -2.451053e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -4.700000e-01
# Newton iteration  0
# err =  0.009973784632854149
# Newton iteration  1
# err =  0.0003475167960245434
# Newton iteration  2
# err =  4.811594482509609e-07
# Newton iteration  3
# err =  9.311182957551943e-13
# 0
# top displacement u_3 = -2.553889e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -4.800000e-01
# Newton iteration  0
# err =  0.010315708816748143
# Newton iteration  1
# err =  0.0004058866156748069
# Newton iteration  2
# err =  7.215099819969447e-07
# Newton iteration  3
# err =  2.3007644064502273e-12
# 0
# top displacement u_3 = -2.664395e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -4.900000e-01
# Newton iteration  0
# err =  0.010719246419062921
# Newton iteration  1
# err =  0.0004850819320566429
# Newton iteration  2
# err =  1.1509698373742181e-06
# Newton iteration  3
# err =  6.5390916424359744e-12
# 0
# top displacement u_3 = -2.784431e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -5.000000e-01
# Newton iteration  0
# err =  0.011207888794401736
# Newton iteration  1
# err =  0.0005979655721218979
# Newton iteration  2
# err =  1.997290696377882e-06
# Newton iteration  3
# err =  2.2500150894331738e-11
# Newton iteration  4
# err =  2.541079231220859e-16
# 0
# top displacement u_3 = -2.916751e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -5.100000e-01
# Newton iteration  0
# err =  0.011820784401429413
# Newton iteration  1
# err =  0.0007702958622032315
# Newton iteration  2
# err =  3.912802092444513e-06
# Newton iteration  3
# err =  1.0213506557726873e-10
# Newton iteration  4
# err =  1.703987429307775e-16
# 0
# top displacement u_3 = -3.065756e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -5.200000e-01
# Newton iteration  0
# err =  0.012630003443966148
# Newton iteration  1
# err =  0.0010617207157406045
# Newton iteration  2
# err =  9.270944779641051e-06
# Newton iteration  3
# err =  7.188049456080171e-10
# Newton iteration  4
# err =  2.4866506028210525e-16
# 0
# top displacement u_3 = -3.239315e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -5.300000e-01
# Newton iteration  0
# err =  0.013789828625240662
# Newton iteration  1
# err =  0.0016460628795476203
# Newton iteration  2
# err =  3.095291411939155e-05
# Newton iteration  3
# err =  1.1314898698069036e-08
# Newton iteration  4
# err =  1.4447947211394862e-15
# 0
# top displacement u_3 = -3.454508e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -5.400000e-01
# Newton iteration  0
# err =  0.015729406667239404
# Newton iteration  1
# err =  0.0033095267718694916
# Newton iteration  2
# err =  0.00023650717817847553
# Newton iteration  3
# err =  1.3771649782147086e-06
# Newton iteration  4
# err =  4.718376085890493e-11
# Newton iteration  5
# err =  2.729959046143501e-16
# 0
# top displacement u_3 = -3.768836e-01
# ------------------------------------------------------------------------------------------------------------------------
# Solve for t_3 = -5.500000e-01
# Newton iteration  0
# err =  0.02069466068752507
# Newton iteration  1
# err =  0.03427927344683124
# Newton iteration  2
# err =  0.12889714425957785
# Newton iteration  3
# err =  0.019147921803972512
# Newton iteration  4
# err =  0.021969613080472756
# Newton iteration  5
# err =  0.03648971628941563
# Newton iteration  6
# err =  0.01871107598821157
# Newton iteration  7
# err =  0.03272576054948231
# Newton iteration  8
# err =  0.1289895080873823
# Newton iteration  9
# err =  0.05365228061062455
# Warning: Newton might not converge! Error =  0.05365228061062455
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [41], line 26
#      24 retcode, iterations = solvers.Newton(Pi, u, maxit=10, inverse="pardiso")
#      25 if retcode != 0:
# ---> 26     raise RuntimeError("Solver failed")
#      27 t_3_data.append(t_3.Get())
#      28 u_top_data.append(u(mesh(0, 0, 0.5))[2])
#
# RuntimeError: Solver failed

# %%
plt.plot(t_3_data, u_top_data)
# Out:
# <div id='194fd9c9-a9a2-4ac1-9dcb-07633c92207e'></div>

# %% [markdown]
# ## Questions
#
#  1. How far can the SVK material be compressed?
#  2. How far can the NH material be compressed?
#  3. What is the key difference between the graphs?
#  4. Do you suspect the "problem" to be rather in the material model or in the FE formulation/solution procedure?
#  5. How would the code look like when the deformation map $\varphi$ is used instead of the displacement field $u$?
